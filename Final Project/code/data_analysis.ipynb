# %%
import pandas as pd
import numpy as np
import nltk
nltk.downloader.download('vader_lexicon')
from nltk.stem.porter import PorterStemmer
import re
from nltk.tokenize import RegexpTokenizer
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
import matplotlib.gridspec as gridspec
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\51968\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
data = pd.read_csv('cleaned-winemag-data-130k-v2.csv', index_col = 0)
data.head(5)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87   25.0  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                             Unknown      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1         taster_name  \
# 0                 Etna       Kerin O’Keefe
# 1              Unknown          Roger Voss
# 2    Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore  Alexander Peartree
# 4    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
# take log value of column price.
data['price_log'] = np.log(data['price'])

# %%
# clean the column description.
# turn every word in column description into lowercase, and remove irrelevent terms.
data['description'] = data['description'].str.lower()
data['description'] = data['description'].apply(lambda elem: re.sub('[^a-zA-Z]',' ', elem))

# %%
# use regular expression to tokenize sentences to list of words.
tokenizer = RegexpTokenizer(r'\w+')
words_descriptions = data['description'].apply(tokenizer.tokenize)

# %%
# when split descriptions into individual words, create list to save all individual words, and add a new feature description lengths into dataset.
all_words = []
for tokens in words_descriptions:
    for word in tokens:
        all_words.append(word)
description_lengths = []
for tokens in words_descriptions:
    description_lengths.append(len(tokens))
data['description_lengths'] = description_lengths
vocabularies = sorted(list(set(all_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_words), len(vocabularies)))
count_all_words = Counter(all_words)
count_all_words.most_common(100)
# Out:
# 4937774 words total, with a vocabulary size of 30452
# [('and', 321309),
#  ('the', 204668),
#  ('a', 166325),
#  ('of', 159396),
#  ('with', 111439),
#  ('this', 104965),
#  ('is', 89535),
#  ('it', 79887),
#  ('wine', 74246),
#  ('flavors', 58016),
#  ('in', 57888),
#  ('to', 51898),
#  ('s', 49361),
#  ('fruit', 46032),
#  ('on', 41934),
#  ('that', 37566),
#  ('aromas', 36229),
#  ('palate', 35107),
#  ('acidity', 32127),
#  ('finish', 32113),
#  ('from', 30057),
#  ('but', 29053),
#  ('tannins', 28452),
#  ('drink', 27880),
#  ('cherry', 26901),
#  ('black', 26638),
#  ('ripe', 25117),
#  ('are', 23832),
#  ('has', 22855),
#  ('for', 20216),
#  ('red', 19966),
#  ('by', 18993),
#  ('spice', 17732),
#  ('notes', 17470),
#  ('an', 16920),
#  ('as', 16898),
#  ('its', 16685),
#  ('oak', 16422),
#  ('rich', 16225),
#  ('fresh', 16035),
#  ('dry', 15945),
#  ('now', 15794),
#  ('berry', 15627),
#  ('nose', 15512),
#  ('full', 14713),
#  ('plum', 13721),
#  ('soft', 12644),
#  ('sweet', 12626),
#  ('fruits', 12489),
#  ('well', 12380),
#  ('apple', 12361),
#  ('blend', 12107),
#  ('blackberry', 11846),
#  ('white', 11821),
#  ('crisp', 11746),
#  ('light', 11634),
#  ('offers', 11518),
#  ('texture', 11442),
#  ('dark', 11399),
#  ('there', 11104),
#  ('citrus', 10781),
#  ('while', 10757),
#  ('shows', 10706),
#  ('bodied', 10510),
#  ('through', 10483),
#  ('vanilla', 10199),
#  ('bright', 10035),
#  ('cabernet', 10006),
#  ('at', 9804),
#  ('very', 9588),
#  ('more', 9431),
#  ('pepper', 9366),
#  ('juicy', 8966),
#  ('green', 8954),
#  ('good', 8873),
#  ('fruity', 8791),
#  ('raspberry', 8780),
#  ('lemon', 8720),
#  ('firm', 8480),
#  ('some', 8362),
#  ('chocolate', 8055),
#  ('peach', 7964),
#  ('balanced', 7829),
#  ('touch', 7799),
#  ('character', 7679),
#  ('not', 7669),
#  ('like', 7639),
#  ('will', 7513),
#  ('dried', 7362),
#  ('years', 7292),
#  ('out', 7268),
#  ('pear', 7254),
#  ('sauvignon', 7155),
#  ('up', 7154),
#  ('structure', 7084),
#  ('or', 7017),
#  ('be', 6760),
#  ('spicy', 6699),
#  ('fine', 6670),
#  ('smooth', 6659)]

# %%
# convert words with same meaning to one single word(e.g. walk, walked, walking ->walk), and delete all stopwords.
stopword_list = stopwords.words('english')
ps = PorterStemmer()
words_descriptions = words_descriptions.apply(lambda elem: [word for word in elem if not word in stopword_list])
words_descriptions = words_descriptions.apply(lambda elem: [ps.stem(word) for word in elem])
data['description_cleaned'] = words_descriptions.apply(lambda elem: ' '.join(elem))

# %%
# checked the cleaned word list.
all_words = []
for tokens in words_descriptions:
    for word in tokens:
        all_words.append(word)
vocabularies = sorted(list(set(all_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_words), len(vocabularies)))
count_all_words = Counter(all_words)
count_all_words.most_common(100)
# Out:
# 3009674 words total, with a vocabulary size of 21654
# [('wine', 76823),
#  ('flavor', 65592),
#  ('fruit', 58926),
#  ('aroma', 37541),
#  ('finish', 37167),
#  ('acid', 36618),
#  ('palat', 35220),
#  ('drink', 31234),
#  ('cherri', 30909),
#  ('tannin', 30397),
#  ('ripe', 26752),
#  ('black', 26666),
#  ('dri', 24411),
#  ('note', 23161),
#  ('spice', 21709),
#  ('rich', 20454),
#  ('red', 20196),
#  ('fresh', 20132),
#  ('berri', 17826),
#  ('show', 17205),
#  ('oak', 16961),
#  ('nose', 15527),
#  ('plum', 15014),
#  ('sweet', 14947),
#  ('full', 14823),
#  ('offer', 14738),
#  ('textur', 14713),
#  ('appl', 13984),
#  ('balanc', 13966),
#  ('blackberri', 13949),
#  ('blend', 13851),
#  ('bodi', 13434),
#  ('age', 13286),
#  ('soft', 13175),
#  ('crisp', 12507),
#  ('well', 12391),
#  ('structur', 12170),
#  ('white', 11972),
#  ('light', 11972),
#  ('dark', 11479),
#  ('fruiti', 11017),
#  ('citru', 10781),
#  ('miner', 10481),
#  ('hint', 10430),
#  ('bright', 10374),
#  ('give', 10269),
#  ('raspberri', 10232),
#  ('vanilla', 10200),
#  ('cabernet', 10171),
#  ('herb', 10102),
#  ('touch', 9676),
#  ('year', 9542),
#  ('pepper', 9531),
#  ('juici', 9340),
#  ('green', 9134),
#  ('lemon', 9096),
#  ('good', 8993),
#  ('peach', 8770),
#  ('concentr', 8711),
#  ('firm', 8675),
#  ('feel', 8447),
#  ('like', 8331),
#  ('charact', 8277),
#  ('pear', 8114),
#  ('chocol', 8056),
#  ('currant', 8029),
#  ('toast', 7998),
#  ('complex', 7898),
#  ('vineyard', 7703),
#  ('fine', 7538),
#  ('open', 7499),
#  ('come', 7286),
#  ('sauvignon', 7181),
#  ('smooth', 7042),
#  ('spici', 6963),
#  ('pinot', 6630),
#  ('wood', 6620),
#  ('make', 6519),
#  ('tast', 6516),
#  ('round', 6495),
#  ('style', 6472),
#  ('eleg', 6466),
#  ('made', 6456),
#  ('inten', 6443),
#  ('bottl', 6418),
#  ('mouth', 6296),
#  ('tart', 6252),
#  ('medium', 6243),
#  ('lead', 6086),
#  ('long', 5977),
#  ('tannic', 5860),
#  ('herbal', 5835),
#  ('lime', 5813),
#  ('also', 5804),
#  ('delici', 5692),
#  ('orang', 5680),
#  ('creami', 5665),
#  ('clean', 5653),
#  ('merlot', 5615),
#  ('licor', 5545)]

# %%
# word frequency analysis on column description.
stopwords = set(STOPWORDS)
newStopWords = ['fruit', "Drink", 'wine', 'drink']
stopwords.update(newStopWords)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data['description_cleaned'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of description', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# same on column title.
wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data['title'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of title', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# word frequency analysis on lowest points.
wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data[data['points']==80]['description_cleaned'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of lowest rated wine', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# word frequency analysis on highest points.
wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data[data['points']>=97]['description_cleaned'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of highest rated wine', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# word frequency analysis on highest prices.
wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data[data['price']>=300]['description_cleaned'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of expensive wine', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# word frequency analysis on lowest prices.
wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, max_words = 300, max_font_size=200, width=1000, height=800, random_state=42,).generate(" ".join(data[data['price']<=10]['description_cleaned'].astype(str)))
plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title('wordcloud of cheap wine', fontsize = 25)
plt.axis('off')
plt.show()

# %%
# save into csv file, use in api development.
data.to_csv('cleaned-description-winemag-data-130k-v2.csv')

# %%
# convert a collection of text documents to a matrix of token counts.
# analyze on N-gram.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.gridspec as gridspec

# %%
# choose 20 most common country, saved into country.
country = data['country'].value_counts()[:10]

grid = gridspec.GridSpec(5, 2)
plt.figure(figsize=(16,7*4))

for n, cat in enumerate(country.index[:10]):
    ax = plt.subplot(grid[n])   
    vectorizer = TfidfVectorizer(ngram_range = (2, 3), min_df=5, stop_words='english', max_df=.5) 
    X = vectorizer.fit_transform(data.loc[(data['country'] == cat)]['description_cleaned']) 
    features = (vectorizer.get_feature_names()) 
    scores = (X.toarray()) 
    
    # get top ranking features 
    sums = X.sum(axis = 0) 
    feature = [] 
    for col, term in enumerate(features): 
        feature.append( (term, sums[0, col] )) 
    ranking = pd.DataFrame(feature, columns = ['term','rank']) 
    words = (ranking.sort_values('rank', ascending = False))[:15]
    
    # plot the figure.
    sns.barplot(x = 'term', y = 'rank', data = words, ax = ax, orient = 'v')
    ax.set_title(f"Wine's from {cat} N-grams (n=2)", fontsize = 19)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
    ax.set_ylabel(' ')
    ax.set_xlabel(" ")

plt.subplots_adjust(top = 0.95, hspace = 0.9, wspace = 0.1)
plt.show()

# %%
# create the sentiment intensity analyze model.
SIA = SentimentIntensityAnalyzer()
# apply model, and create variables.
# use sentiment analysis to give polarity score, neutral score, negative score, positive score and overall sentiment to each description.
sentiment = data.copy()
sentiment['polarity_score'] = sentiment['description_cleaned'].apply(lambda x: SIA.polarity_scores(x)['compound'])
sentiment['neutral_score'] = sentiment['description_cleaned'].apply(lambda x: SIA.polarity_scores(x)['neu'])
sentiment['negative_score'] = sentiment['description_cleaned'].apply(lambda x: SIA.polarity_scores(x)['neg'])
sentiment['positive_score'] = sentiment['description_cleaned'].apply(lambda x: SIA.polarity_scores(x)['pos'])

sentiment['sentiment']= np.nan
sentiment.loc[sentiment.polarity_score > 0,'sentiment']='POSITIVE'
sentiment.loc[sentiment.polarity_score ==0,'sentiment']='NEUTRAL'
sentiment.loc[sentiment.polarity_score < 0,'sentiment']='NEGATIVE'

# %%
def sentiment_analyzer_scores(sentence):
    score = SIA.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
sentiment_analyzer_scores('happy')
# Out:
# happy----------------------------------- {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5719}

# %%
plt.figure(figsize=(14,5))

plt.suptitle('Sentiment of the reviews by: \n wine points and price(log)', size=22)

plt.subplot(121)
ax = sns.boxplot(x='sentiment', y='points', data = sentiment, palette = 'pastel')
ax.set_title("Sentiment by wine points distribution", fontsize=19)
ax.set_ylabel("wine points ", fontsize=17)
ax.set_xlabel("sentiment label", fontsize=17)

plt.subplot(122)
ax1= sns.boxplot(x='sentiment', y='price_log', data = sentiment, palette = 'pastel')
ax1.set_title("Sentiment by wine price distribution", fontsize=19)
ax1.set_ylabel("wine price (log) ", fontsize=17)
ax1.set_xlabel("sentiment label", fontsize=17)

plt.subplots_adjust(top = 0.75, wspace=.2)
plt.show()
